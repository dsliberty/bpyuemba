# %% [markdown]
# <h1 align = 'center'>Transfering a Dataset from Google BigQuery to AWS S3</h1>

# %% [markdown]
# # Read data from Google BigQuery

# %% [markdown]
# <h3>Links:</h3>
# <ol>
#     <li><a href = https://cloud.google.com/bigquery/public-data/>Google Big Query</a></li>
#     <li><a href = https://cloud.google.com/public-datasets/>Google Public Datasets</a></li>
# </ol>

# %% [markdown]
# Create and download credentials for the query job:  <a href = 'https://cloud.google.com/bigquery/docs/reference/libraries'>Instructions</a>

# %%
import os
import pandas as pd
from google.cloud import bigquery

cwd = os.getcwd()
try:
    os.makedirs(cwd+'\data')
except:
    pass

# %%
cwd
# Out:
# '/content'

# %% [markdown]
# <h4>Listing Tables in  Medicare Dataset from Big Query</h4>

# %% [markdown]
# Creating connection to open medicare dataset on google BigQuery

# %%
#replace 'cred.json' with the path to your credentials
bq = bigquery.Client.from_service_account_json('/sds-daas-production-bcc88a461e41.json')

# %% [markdown]
# Listing all table names from the medicare database

# %%
tablenames = bq.query("""SELECT * FROM `sds-daas-production:od_riverbend.__TABLES__`""").result()
tables = [i for i in tablenames]
files = [i[2] for i in tables]

# %% [markdown]
# List of tables and corresponding file sizes in Mb

# %%
[str(i[2])+';    '+str(round((i[6]/(1024.0))/1024.0,2))+' Mb' for i in tables]
# Out:
# ['_sdc_primary_keys;    0.0 Mb',
#  '_sdc_rejected;    2285.46 Mb',
#  'account;    0.0 Mb',
#  'adjustment;    1.96 Mb',
#  'alertcategory;    0.0 Mb',
#  'alertcategorylink;    0.0 Mb',
#  'alertitem;    0.0 Mb',
#  'alertread;    0.0 Mb',
#  'alertsub;    0.0 Mb',
#  'allergy;    0.05 Mb',
#  'allergydef;    0.01 Mb',
#  'appointment;    18.39 Mb',
#  'appointmenttype;    0.0 Mb',
#  'apptreminderrule;    0.0 Mb',
#  'apptview;    0.0 Mb',
#  'apptviewitem;    0.0 Mb',
#  'autocode;    0.0 Mb',
#  'autocodecond;    0.0 Mb',
#  'autocodeitem;    0.0 Mb',
#  'autonote;    0.0 Mb',
#  'autonotecontrol;    0.0 Mb',
#  'benefit;    5.83 Mb',
#  'canadiannetwork;    0.0 Mb',
#  'carrier;    0.57 Mb',
#  'claim;    22.06 Mb',
#  'claimform;    0.0 Mb',
#  'claimformitem;    0.15 Mb',
#  'claimpayment;    7.73 Mb',
#  'claimproc;    105.76 Mb',
#  'clearinghouse;    0.0 Mb',
#  'codesystem;    0.0 Mb',
#  'commlog;    19.44 Mb',
#  'commoptout;    0.0 Mb',
#  'computer;    0.0 Mb',
#  'computerpref;    0.0 Mb',
#  'covcat;    0.0 Mb',
#  'covspan;    0.0 Mb',
#  'custreference;    0.0 Mb',
#  'databasemaintenance;    0.02 Mb',
#  'definition;    0.04 Mb',
#  'deflink;    0.0 Mb',
#  'deposit;    0.0 Mb',
#  'disease;    0.17 Mb',
#  'diseasedef;    0.01 Mb',
#  'displayfield;    0.0 Mb',
#  'displayreport;    0.01 Mb',
#  'documentmisc;    178.68 Mb',
#  'ebill;    0.0 Mb',
#  'ehrmeasure;    0.0 Mb',
#  'ehrmeasureevent;    0.0 Mb',
#  'ehrpatient;    0.0 Mb',
#  'electid;    0.07 Mb',
#  'emailhostingtemplate;    0.01 Mb',
#  'employee;    0.0 Mb',
#  'employer;    0.08 Mb',
#  'entrylog;    0.0 Mb',
#  'eservicesignal;    0.0 Mb',
#  'fee;    20.31 Mb',
#  'feesched;    0.17 Mb',
#  'grouppermission;    0.04 Mb',
#  'guardian;    0.0 Mb',
#  'histappointment;    0.05 Mb',
#  'inseditlog;    0.0 Mb',
#  'inseditpatlog;    0.0 Mb',
#  'insfilingcode;    0.0 Mb',
#  'insplan;    0.94 Mb',
#  'inssub;    0.82 Mb',
#  'insverify;    0.81 Mb',
#  'labcase;    0.0 Mb',
#  'laboratory;    0.0 Mb',
#  'language;    0.04 Mb',
#  'medication;    0.03 Mb',
#  'medicationpat;    0.09 Mb',
#  'operatory;    0.0 Mb',
#  'orthocharttab;    0.0 Mb',
#  'patfield;    1.38 Mb',
#  'patfielddef;    0.0 Mb',
#  'patient;    4.38 Mb',
#  'patientnote;    0.98 Mb',
#  'patplan;    0.57 Mb',
#  'payment;    7.34 Mb',
#  'payplan;    0.0 Mb',
#  'payplancharge;    0.0 Mb',
#  'paysplit;    52.23 Mb',
#  'perioexam;    0.45 Mb',
#  'periomeasure;    24.84 Mb',
#  'plannedappt;    0.0 Mb',
#  'popup;    0.13 Mb',
#  'preference;    0.08 Mb',
#  'procbutton;    0.02 Mb',
#  'procbuttonitem;    0.01 Mb',
#  'procbuttonquick;    0.0 Mb',
#  'procedurecode;    0.25 Mb',
#  'procedurelog;    68.12 Mb',
#  'procgroupitem;    0.0 Mb',
#  'procnote;    3.09 Mb',
#  'program;    0.02 Mb',
#  'programproperty;    0.03 Mb',
#  'provider;    0.01 Mb',
#  'providerclinic;    0.0 Mb',
#  'quickpastecat;    0.0 Mb',
#  'quickpastenote;    0.0 Mb',
#  'recall;    0.94 Mb',
#  'recalltrigger;    0.0 Mb',
#  'recalltype;    0.0 Mb',
#  'refattach;    0.11 Mb',
#  'referral;    0.06 Mb',
#  'rxdef;    0.0 Mb',
#  'rxpat;    0.04 Mb',
#  'schedule;    1.01 Mb',
#  'scheduleop;    0.62 Mb',
#  'securitylog;    8.73 Mb',
#  'securityloghash;    4.47 Mb',
#  'sigbutdef;    0.0 Mb',
#  'sigelementdef;    0.42 Mb',
#  'sigmessage;    0.0 Mb',
#  'signalod;    0.06 Mb',
#  'stateabbr;    0.0 Mb',
#  'task;    0.0 Mb',
#  'taskancestor;    0.0 Mb',
#  'tasklist;    0.0 Mb',
#  'tmpclaim_bak_conv;    24.22 Mb',
#  'tmpdcattach;    2.1 Mb',
#  'tmpdcdoc;    2.4 Mb',
#  'tmpdcdoctype;    0.0 Mb',
#  'tmppatient_bak_address;    0.8 Mb',
#  'tmppatviper;    0.86 Mb',
#  'tmpproccodefix_bak;    0.24 Mb',
#  'toolbutitem;    0.01 Mb',
#  'toothinitial;    3.22 Mb',
#  'treatplan;    0.01 Mb',
#  'treatplanattach;    0.01 Mb',
#  'updatehistory;    0.0 Mb',
#  'usergroup;    0.0 Mb',
#  'usergroupattach;    0.0 Mb',
#  'userod;    0.0 Mb',
#  'userodapptview;    0.0 Mb',
#  'userodpref;    0.0 Mb',
#  'userquery;    0.0 Mb',
#  'wikipage;    0.0 Mb',
#  'zipcode;    0.02 Mb']

# %% [markdown]
# <h4>Downloading Medicare Datasets from Big Query</h4>

# %%
len(tables)
# Out:
# 141

# %% [markdown]
# <br>
# Downloading tables containing inpatient and outpatient charges as csv files, larger files may be be included in the analysis later on.
# <br><br>
# (check file sizes before downloading, BigQuery ~= Big Data)
# <br>

# %%
for i in files[0:len(tables)]:
    j = 'sds-daas-production.od_riverbend.'+i
    filequery = bq.query("""SELECT * FROM """ + '`'+j+'`').result()
    filedf = filequery.to_dataframe()
    filedf.to_csv(cwd+'/data/'+i+'.csv', index= False)

# %% [markdown]
# <br>
# Listing downloaded files
# <br>

# %%
data = os.listdir(cwd+'/data/')
len(data)
print(data)
# Out:
# ['clearinghouse.csv', 'claimpayment.csv', 'databasemaintenance.csv', 'appointment.csv', 'wikipage.csv', 'userodapptview.csv', 'laboratory.csv', 'tmppatviper.csv', 'recall.csv', 'canadiannetwork.csv', 'medicationpat.csv', 'inseditpatlog.csv', 'patient.csv', 'toothinitial.csv', 'grouppermission.csv', 'autocodeitem.csv', 'language.csv', 'recalltype.csv', 'scheduleop.csv', 'tmpproccodefix_bak.csv', 'patientnote.csv', 'employee.csv', 'signalod.csv', 'entrylog.csv', 'program.csv', 'ehrmeasure.csv', 'task.csv', 'claimform.csv', 'custreference.csv', 'schedule.csv', 'preference.csv', 'quickpastenote.csv', 'recalltrigger.csv', 'apptviewitem.csv', 'account.csv', 'userodpref.csv', 'emailhostingtemplate.csv', 'claimformitem.csv', 'taskancestor.csv', 'deflink.csv', 'commlog.csv', 'userquery.csv', 'plannedappt.csv', 'claim.csv', 'securitylog.csv', 'quickpastecat.csv', 'referral.csv', 'covspan.csv', 'sigmessage.csv', 'procnote.csv', 'securityloghash.csv', 'treatplanattach.csv', 'provider.csv', 'adjustment.csv', 'ebill.csv', 'allergydef.csv', 'insplan.csv', 'treatplan.csv', 'medication.csv', 'patfield.csv', 'procbutton.csv', 'insverify.csv', 'benefit.csv', 'toolbutitem.csv', 'procbuttonitem.csv', 'feesched.csv', 'providerclinic.csv', 'perioexam.csv', 'paysplit.csv', 'usergroup.csv', 'rxdef.csv', 'electid.csv', 'procedurelog.csv', 'zipcode.csv', 'alertcategory.csv', 'appointmenttype.csv', 'apptreminderrule.csv', 'procedurecode.csv', 'payplancharge.csv', 'histappointment.csv', 'diseasedef.csv', 'autonote.csv', 'disease.csv', 'displayfield.csv', 'alertsub.csv', 'autocodecond.csv', 'programproperty.csv', 'autonotecontrol.csv', 'userod.csv', 'tmpdcdoc.csv', 'payplan.csv', 'tmppatient_bak_address.csv', 'usergroupattach.csv', 'deposit.csv', 'commoptout.csv', 'tmpdcattach.csv', 'guardian.csv', 'orthocharttab.csv', 'tmpdcdoctype.csv', 'allergy.csv', 'insfilingcode.csv', 'inssub.csv', 'payment.csv', 'eservicesignal.csv', 'operatory.csv', '_sdc_rejected.csv', 'computerpref.csv', 'alertcategorylink.csv', 'patfielddef.csv', 'periomeasure.csv', 'procgroupitem.csv', 'stateabbr.csv', 'popup.csv', 'refattach.csv', 'alertread.csv', 'alertitem.csv', 'covcat.csv', 'tasklist.csv', 'patplan.csv', 'documentmisc.csv', 'employer.csv', 'fee.csv', '_sdc_primary_keys.csv', 'labcase.csv', 'carrier.csv', 'displayreport.csv', 'ehrmeasureevent.csv', 'inseditlog.csv', 'apptview.csv', 'definition.csv', 'sigelementdef.csv', 'updatehistory.csv', 'procbuttonquick.csv', 'sigbutdef.csv', 'autocode.csv', 'codesystem.csv', 'claimproc.csv', 'rxpat.csv', 'ehrpatient.csv', 'computer.csv', 'tmpclaim_bak_conv.csv']

# %% [markdown]
# # Load Data into Google Cloud Storage

# %%
from google.colab import auth
auth.authenticate_user()

# https://cloud.google.com/resource-manager/docs/creating-managing-projects
project_id = 'storied-link-291421'
# !gcloud config set project {project_id}
# Out:
# Updated property [core/project].

# %%
# Create a local file with data to upload.
with open('/tmp/to_upload.txt', 'w') as f:
  f.write('my sample file')

import uuid

# Make a unique bucket to which we'll upload the file.
# (GCS buckets are part of a single global namespace.)
bucket_name = 'colab-test' + str(uuid.uuid1())

# Full reference: https://cloud.google.com/storage/docs/gsutil/commands/mb
# !gsutil mb gs://{bucket_name}

# Copy the file to our new bucket.
# Full reference: https://cloud.google.com/storage/docs/gsutil/commands/cp
# !gsutil cp /tmp/to_upload.txt gs://{bucket_name}/
  
# Finally, dump the contents of our newly copied file to make sure everything worked.
# !gsutil cat gs://{bucket_name}/to_upload.txt
# Out:
# Creating gs://colab-test5803c458-c18d-11eb-a7dc-0242ac1c0002/...
# Copying file:///tmp/to_upload.txt [Content-Type=text/plain]...
# / [1 files][   14.0 B/   14.0 B]
# Operation completed over 1 objects/14.0 B.
# my sample file

# %%
bucket_name = 'c339c7c1-2ba5-4aed-bd5c-f26c8c323e9a'
# !gsutil cp /content/data/* gs://{bucket_name}/
# Out:
# Copying file:///content/data/account.csv [Content-Type=text/csv]...
# Copying file:///content/data/adjustment.csv [Content-Type=text/csv]...
# Copying file:///content/data/alertcategory.csv [Content-Type=text/csv]...
# Copying file:///content/data/alertcategorylink.csv [Content-Type=text/csv]...
# - [4 files][  3.4 MiB/  3.4 MiB]
# ==> NOTE: You are performing a sequence of gsutil operations that may
# run significantly faster if you instead use gsutil -m cp ... Please
# see the -m section under "gsutil help options" for further information
# about when gsutil -m can be advantageous.
#
# Copying file:///content/data/alertitem.csv [Content-Type=text/csv]...
# Copying file:///content/data/alertread.csv [Content-Type=text/csv]...
# Copying file:///content/data/alertsub.csv [Content-Type=text/csv]...
# Copying file:///content/data/allergy.csv [Content-Type=text/csv]...
# Copying file:///content/data/allergydef.csv [Content-Type=text/csv]...
# Copying file:///content/data/appointment.csv [Content-Type=text/csv]...
# Copying file:///content/data/appointmenttype.csv [Content-Type=text/csv]...
# Copying file:///content/data/apptreminderrule.csv [Content-Type=text/csv]...
# Copying file:///content/data/apptview.csv [Content-Type=text/csv]...
# Copying file:///content/data/apptviewitem.csv [Content-Type=text/csv]...
# Copying file:///content/data/autocodecond.csv [Content-Type=text/csv]...
# Copying file:///content/data/autocode.csv [Content-Type=text/csv]...
# Copying file:///content/data/autocodeitem.csv [Content-Type=text/csv]...
# Copying file:///content/data/autonotecontrol.csv [Content-Type=text/csv]...
# Copying file:///content/data/autonote.csv [Content-Type=text/csv]...
# Copying file:///content/data/benefit.csv [Content-Type=text/csv]...
# Copying file:///content/data/canadiannetwork.csv [Content-Type=text/csv]...
# Copying file:///content/data/carrier.csv [Content-Type=text/csv]...
# Copying file:///content/data/claim.csv [Content-Type=text/csv]...
# Copying file:///content/data/claimform.csv [Content-Type=text/csv]...
# Copying file:///content/data/claimformitem.csv [Content-Type=text/csv]...
# Copying file:///content/data/claimpayment.csv [Content-Type=text/csv]...
# Copying file:///content/data/claimproc.csv [Content-Type=text/csv]...
# Caught CTRL-C (signal 2) - exiting
# ^C

# %% [markdown]
# # AWS

# %% [markdown]
# ## AWS Setup

# %%
# AWS CLI for python = boto3
# !pip install boto3
import boto3
print('boto3 installed and imported!')
# Out:
# Requirement already satisfied: boto3 in /usr/local/lib/python3.7/dist-packages (1.17.84)
# Requirement already satisfied: botocore<1.21.0,>=1.20.84 in /usr/local/lib/python3.7/dist-packages (from boto3) (1.20.84)
# Requirement already satisfied: s3transfer<0.5.0,>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from boto3) (0.4.2)
# Requirement already satisfied: jmespath<1.0.0,>=0.7.1 in /usr/local/lib/python3.7/dist-packages (from boto3) (0.10.0)
# Requirement already satisfied: urllib3<1.27,>=1.25.4 in /usr/local/lib/python3.7/dist-packages (from botocore<1.21.0,>=1.20.84->boto3) (1.26.5)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /usr/local/lib/python3.7/dist-packages (from botocore<1.21.0,>=1.20.84->boto3) (2.8.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil<3.0.0,>=2.1->botocore<1.21.0,>=1.20.84->boto3) (1.15.0)
# boto3 installed and imported!

# %%
# Authenticate on AWS
s3r = boto3.resource('s3', aws_access_key_id='AKIARVDVLVQOXAEKXQQB',
    aws_secret_access_key='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')
buck = s3r.Bucket('c339c7c1-2ba5-4aed-bd5c-f26c8c323e9a')

#buck.download_file(remotefilename,localfilename)

for bucket in s3r.buckets.all():
    print(bucket.name)
# Out:
# aws-athena-query-results-us-east-2-114062765085
# byu2022-npi
# c339c7c1-2ba5-4aed-bd5c-f26c8c323e9a
# sagemaker-studio-dml4dpef6oc

# %% [markdown]
# ## Write CSV to S3

# %%
#!/usr/bin/env python

import glob
import boto3
import os

BUCKET_NAME = 'c339c7c1-2ba5-4aed-bd5c-f26c8c323e9a'
FOLDER_NAME = '/content/data'

#session = boto3.Session(profile_name='default')
s3 = boto3.resource('s3', aws_access_key_id='AKIARVDVLVQOXAEKXQQB',
    aws_secret_access_key='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')
csv_files = glob.glob("/content/data/*.csv")

for filename in csv_files:
    key = "%s/%s" % (FOLDER_NAME, os.path.basename(filename))
    print("Putting %s as %s" % (filename,key))
    s3.Bucket(BUCKET_NAME).upload_file(key, key)

print("All_Done")
# Out:
# Putting /content/data/clearinghouse.csv as /content/data/clearinghouse.csv
# Putting /content/data/claimpayment.csv as /content/data/claimpayment.csv
# Putting /content/data/databasemaintenance.csv as /content/data/databasemaintenance.csv
# Putting /content/data/appointment.csv as /content/data/appointment.csv
# Putting /content/data/wikipage.csv as /content/data/wikipage.csv
# Putting /content/data/userodapptview.csv as /content/data/userodapptview.csv
# Putting /content/data/laboratory.csv as /content/data/laboratory.csv
# Putting /content/data/tmppatviper.csv as /content/data/tmppatviper.csv
# Putting /content/data/recall.csv as /content/data/recall.csv
# Putting /content/data/canadiannetwork.csv as /content/data/canadiannetwork.csv
# Putting /content/data/medicationpat.csv as /content/data/medicationpat.csv
# Putting /content/data/inseditpatlog.csv as /content/data/inseditpatlog.csv
# Putting /content/data/patient.csv as /content/data/patient.csv
# Putting /content/data/toothinitial.csv as /content/data/toothinitial.csv
# Putting /content/data/grouppermission.csv as /content/data/grouppermission.csv
# Putting /content/data/autocodeitem.csv as /content/data/autocodeitem.csv
# Putting /content/data/language.csv as /content/data/language.csv
# Putting /content/data/recalltype.csv as /content/data/recalltype.csv
# Putting /content/data/scheduleop.csv as /content/data/scheduleop.csv
# Putting /content/data/tmpproccodefix_bak.csv as /content/data/tmpproccodefix_bak.csv
# Putting /content/data/patientnote.csv as /content/data/patientnote.csv
# Putting /content/data/employee.csv as /content/data/employee.csv
# Putting /content/data/signalod.csv as /content/data/signalod.csv
# Putting /content/data/entrylog.csv as /content/data/entrylog.csv
# Putting /content/data/program.csv as /content/data/program.csv
# Putting /content/data/ehrmeasure.csv as /content/data/ehrmeasure.csv
# Putting /content/data/task.csv as /content/data/task.csv
# Putting /content/data/claimform.csv as /content/data/claimform.csv
# Putting /content/data/custreference.csv as /content/data/custreference.csv
# Putting /content/data/schedule.csv as /content/data/schedule.csv
# Putting /content/data/preference.csv as /content/data/preference.csv
# Putting /content/data/quickpastenote.csv as /content/data/quickpastenote.csv
# Putting /content/data/recalltrigger.csv as /content/data/recalltrigger.csv
# Putting /content/data/apptviewitem.csv as /content/data/apptviewitem.csv
# Putting /content/data/account.csv as /content/data/account.csv
# Putting /content/data/userodpref.csv as /content/data/userodpref.csv
# Putting /content/data/emailhostingtemplate.csv as /content/data/emailhostingtemplate.csv
# Putting /content/data/claimformitem.csv as /content/data/claimformitem.csv
# Putting /content/data/taskancestor.csv as /content/data/taskancestor.csv
# Putting /content/data/deflink.csv as /content/data/deflink.csv
# Putting /content/data/commlog.csv as /content/data/commlog.csv
# Putting /content/data/userquery.csv as /content/data/userquery.csv
# Putting /content/data/plannedappt.csv as /content/data/plannedappt.csv
# Putting /content/data/claim.csv as /content/data/claim.csv
# Putting /content/data/securitylog.csv as /content/data/securitylog.csv
# Putting /content/data/quickpastecat.csv as /content/data/quickpastecat.csv
# Putting /content/data/referral.csv as /content/data/referral.csv
# Putting /content/data/covspan.csv as /content/data/covspan.csv
# Putting /content/data/sigmessage.csv as /content/data/sigmessage.csv
# Putting /content/data/procnote.csv as /content/data/procnote.csv
# Putting /content/data/securityloghash.csv as /content/data/securityloghash.csv
# Putting /content/data/treatplanattach.csv as /content/data/treatplanattach.csv
# Putting /content/data/provider.csv as /content/data/provider.csv
# Putting /content/data/adjustment.csv as /content/data/adjustment.csv
# Putting /content/data/ebill.csv as /content/data/ebill.csv
# Putting /content/data/allergydef.csv as /content/data/allergydef.csv
# Putting /content/data/insplan.csv as /content/data/insplan.csv
# Putting /content/data/treatplan.csv as /content/data/treatplan.csv
# Putting /content/data/medication.csv as /content/data/medication.csv
# Putting /content/data/patfield.csv as /content/data/patfield.csv
# Putting /content/data/procbutton.csv as /content/data/procbutton.csv
# Putting /content/data/insverify.csv as /content/data/insverify.csv
# Putting /content/data/benefit.csv as /content/data/benefit.csv
# Putting /content/data/toolbutitem.csv as /content/data/toolbutitem.csv
# Putting /content/data/procbuttonitem.csv as /content/data/procbuttonitem.csv
# Putting /content/data/feesched.csv as /content/data/feesched.csv
# Putting /content/data/providerclinic.csv as /content/data/providerclinic.csv
# Putting /content/data/perioexam.csv as /content/data/perioexam.csv
# Putting /content/data/paysplit.csv as /content/data/paysplit.csv
# Putting /content/data/usergroup.csv as /content/data/usergroup.csv
# Putting /content/data/rxdef.csv as /content/data/rxdef.csv
# Putting /content/data/electid.csv as /content/data/electid.csv
# Putting /content/data/procedurelog.csv as /content/data/procedurelog.csv
# Putting /content/data/zipcode.csv as /content/data/zipcode.csv
# Putting /content/data/alertcategory.csv as /content/data/alertcategory.csv
# Putting /content/data/appointmenttype.csv as /content/data/appointmenttype.csv
# Putting /content/data/apptreminderrule.csv as /content/data/apptreminderrule.csv
# Putting /content/data/procedurecode.csv as /content/data/procedurecode.csv
# Putting /content/data/payplancharge.csv as /content/data/payplancharge.csv
# Putting /content/data/histappointment.csv as /content/data/histappointment.csv
# Putting /content/data/diseasedef.csv as /content/data/diseasedef.csv
# Putting /content/data/autonote.csv as /content/data/autonote.csv
# Putting /content/data/disease.csv as /content/data/disease.csv
# Putting /content/data/displayfield.csv as /content/data/displayfield.csv
# Putting /content/data/alertsub.csv as /content/data/alertsub.csv
# Putting /content/data/autocodecond.csv as /content/data/autocodecond.csv
# Putting /content/data/programproperty.csv as /content/data/programproperty.csv
# Putting /content/data/autonotecontrol.csv as /content/data/autonotecontrol.csv
# Putting /content/data/userod.csv as /content/data/userod.csv
# Putting /content/data/tmpdcdoc.csv as /content/data/tmpdcdoc.csv
# Putting /content/data/payplan.csv as /content/data/payplan.csv
# Putting /content/data/tmppatient_bak_address.csv as /content/data/tmppatient_bak_address.csv
# Putting /content/data/usergroupattach.csv as /content/data/usergroupattach.csv
# Putting /content/data/deposit.csv as /content/data/deposit.csv
# Putting /content/data/commoptout.csv as /content/data/commoptout.csv
# Putting /content/data/tmpdcattach.csv as /content/data/tmpdcattach.csv
# Putting /content/data/guardian.csv as /content/data/guardian.csv
# Putting /content/data/orthocharttab.csv as /content/data/orthocharttab.csv
# Putting /content/data/tmpdcdoctype.csv as /content/data/tmpdcdoctype.csv
# Putting /content/data/allergy.csv as /content/data/allergy.csv
# Putting /content/data/insfilingcode.csv as /content/data/insfilingcode.csv
# Putting /content/data/inssub.csv as /content/data/inssub.csv
# Putting /content/data/payment.csv as /content/data/payment.csv
# Putting /content/data/eservicesignal.csv as /content/data/eservicesignal.csv
# Putting /content/data/operatory.csv as /content/data/operatory.csv
# Putting /content/data/_sdc_rejected.csv as /content/data/_sdc_rejected.csv
# Putting /content/data/computerpref.csv as /content/data/computerpref.csv
# Putting /content/data/alertcategorylink.csv as /content/data/alertcategorylink.csv
# Putting /content/data/patfielddef.csv as /content/data/patfielddef.csv
# Putting /content/data/periomeasure.csv as /content/data/periomeasure.csv
# Putting /content/data/procgroupitem.csv as /content/data/procgroupitem.csv
# Putting /content/data/stateabbr.csv as /content/data/stateabbr.csv
# Putting /content/data/popup.csv as /content/data/popup.csv
# Putting /content/data/refattach.csv as /content/data/refattach.csv
# Putting /content/data/alertread.csv as /content/data/alertread.csv
# Putting /content/data/alertitem.csv as /content/data/alertitem.csv
# Putting /content/data/covcat.csv as /content/data/covcat.csv
# Putting /content/data/tasklist.csv as /content/data/tasklist.csv
# Putting /content/data/patplan.csv as /content/data/patplan.csv
# Putting /content/data/documentmisc.csv as /content/data/documentmisc.csv
# Putting /content/data/employer.csv as /content/data/employer.csv
# Putting /content/data/fee.csv as /content/data/fee.csv
# Putting /content/data/_sdc_primary_keys.csv as /content/data/_sdc_primary_keys.csv
# Putting /content/data/labcase.csv as /content/data/labcase.csv
# Putting /content/data/carrier.csv as /content/data/carrier.csv
# Putting /content/data/displayreport.csv as /content/data/displayreport.csv
# Putting /content/data/ehrmeasureevent.csv as /content/data/ehrmeasureevent.csv
# Putting /content/data/inseditlog.csv as /content/data/inseditlog.csv
# Putting /content/data/apptview.csv as /content/data/apptview.csv
# Putting /content/data/definition.csv as /content/data/definition.csv
# Putting /content/data/sigelementdef.csv as /content/data/sigelementdef.csv
# Putting /content/data/updatehistory.csv as /content/data/updatehistory.csv
# Putting /content/data/procbuttonquick.csv as /content/data/procbuttonquick.csv
# Putting /content/data/sigbutdef.csv as /content/data/sigbutdef.csv
# Putting /content/data/autocode.csv as /content/data/autocode.csv
# Putting /content/data/codesystem.csv as /content/data/codesystem.csv
# Putting /content/data/claimproc.csv as /content/data/claimproc.csv
# Putting /content/data/rxpat.csv as /content/data/rxpat.csv
# Putting /content/data/ehrpatient.csv as /content/data/ehrpatient.csv
# Putting /content/data/computer.csv as /content/data/computer.csv
# Putting /content/data/tmpclaim_bak_conv.csv as /content/data/tmpclaim_bak_conv.csv
# All_Done
